# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
covid=pd.read_csv('aggregate_covid_country.csv')
covid.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-22      Albania          0          0       0
# 2  2020-01-22      Algeria          0          0       0
# 3  2020-01-22      Andorra          0          0       0
# 4  2020-01-22       Angola          0          0       0

# %%
covid.tail()
# Out:
#              Date             Country  Confirmed  Recovered  Deaths
# 23683  2020-05-26  West Bank and Gaza        429        365       3
# 23684  2020-05-26      Western Sahara          9          6       1
# 23685  2020-05-26               Yemen        249         10      49
# 23686  2020-05-26              Zambia        920        336       7
# 23687  2020-05-26            Zimbabwe         56         25       4

# %%
df=pd.DataFrame(data=covid)

# %%
df.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-22      Albania          0          0       0
# 2  2020-01-22      Algeria          0          0       0
# 3  2020-01-22      Andorra          0          0       0
# 4  2020-01-22       Angola          0          0       0

# %%
df.head(20)
# Out:
#           Date              Country  Confirmed  Recovered  Deaths
# 0   2020-01-22          Afghanistan          0          0       0
# 1   2020-01-22              Albania          0          0       0
# 2   2020-01-22              Algeria          0          0       0
# 3   2020-01-22              Andorra          0          0       0
# 4   2020-01-22               Angola          0          0       0
# 5   2020-01-22  Antigua and Barbuda          0          0       0
# 6   2020-01-22            Argentina          0          0       0
# 7   2020-01-22              Armenia          0          0       0
# 8   2020-01-22            Australia          0          0       0
# 9   2020-01-22              Austria          0          0       0
# 10  2020-01-22           Azerbaijan          0          0       0
# 11  2020-01-22              Bahamas          0          0       0
# 12  2020-01-22              Bahrain          0          0       0
# ...

# %%
df.tail(20)
# Out:
#              Date               Country  Confirmed  Recovered  Deaths
# 23668  2020-05-26              Thailand       3045       2929      57
# 23669  2020-05-26           Timor-Leste         24         24       0
# 23670  2020-05-26                  Togo        391        177      13
# 23671  2020-05-26   Trinidad and Tobago        116        108       8
# 23672  2020-05-26               Tunisia       1051        929      48
# 23673  2020-05-26                Turkey     158762     121507    4397
# 23674  2020-05-26                    US    1680913     384902   98913
# 23675  2020-05-26                Uganda        253         69       0
# 23676  2020-05-26               Ukraine      21584       7575     644
# 23677  2020-05-26  United Arab Emirates      31086      15982     253
# 23678  2020-05-26        United Kingdom     266599       1161   37130
# 23679  2020-05-26               Uruguay        789        638      22
# ...

# %%
df.isnull()
# Out:
#         Date  Country  Confirmed  Recovered  Deaths
# 0      False    False      False      False   False
# 1      False    False      False      False   False
# 2      False    False      False      False   False
# 3      False    False      False      False   False
# 4      False    False      False      False   False
# ...      ...      ...        ...        ...     ...
# 23683  False    False      False      False   False
# 23684  False    False      False      False   False
# 23685  False    False      False      False   False
# 23686  False    False      False      False   False
# 23687  False    False      False      False   False
#
# [23688 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 5 columns):
# Date         23688 non-null object
# Country      23688 non-null object
# Confirmed    23688 non-null int64
# Recovered    23688 non-null int64
# Deaths       23688 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 925.4+ KB

# %%
df.dtypes
# Out:
# Date         object
# Country      object
# Confirmed     int64
# Recovered     int64
# Deaths        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date', 'Country', 'Confirmed', 'Recovered', 'Deaths'], dtype='object')

# %%
df['Country'].value_counts()
# Out:
# Ethiopia                            126
# Ecuador                             126
# Iraq                                126
# India                               126
# Brazil                              126
#                                    ...
# Saint Vincent and the Grenadines    126
# Albania                             126
# Maldives                            126
# Senegal                             126
# Croatia                             126
# Name: Country, Length: 188, dtype: int64

# %%
df.shape
# Out:
# (23688, 5)

# %%
df['active']=df['Confirmed']-df['Deaths']-df['Recovered']

# %%
df['Recovered'].plot.hist()

# %%
sns.set_style('whitegrid')
sns.countplot(x='Recovered',data=df)

# %%
#sns.set_style('dark')
#sns.countplot(x='Deaths',hue='Country',data=df,palette='rainbow')

# %%
sns.distplot(df['Deaths'],kde=False,color='Blue',bins=50)

# %%
sns.countplot(x='Deaths',data=df)

# %%
sns.set_style('dark')
plt.figure(figsize=(6,8))
sns.boxplot(x='Confirmed',y='Recovered',data=df,palette='GnBu')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 6 columns):
# Date         23688 non-null object
# Country      23688 non-null object
# Confirmed    23688 non-null int64
# Recovered    23688 non-null int64
# Deaths       23688 non-null int64
# active       23688 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# Date         object
# Country      object
# Confirmed     int64
# Recovered     int64
# Deaths        int64
# active        int64
# dtype: object

# %%
con_n={'Country':str}
df.astype(con_n)
print(df.dtypes)
# Out:
# Date         object
# Country      object
# Confirmed     int64
# Recovered     int64
# Deaths        int64
# active        int64
# dtype: object

# %%
top=df[df['Date']==df['Date'].max()]
world=top.groupby('Country')['Confirmed','active','Deaths'].sum().reset_index()
world.head()
# Out:
#        Country  Confirmed  active  Deaths
# 0  Afghanistan      11831   10483     220
# 1      Albania       1029     193      33
# 2      Algeria       8697    3162     617
# 3      Andorra        763      36      51
# 4       Angola         70      48       4

# %%
plt.figure(figsize=(25,10))
plt.xlabel("Dates",fontsize=20)
plt.xticks(rotation = 90,fontsize=10)
plt.yticks(fontsize=15)
plt.ylabel("Total Cases",fontsize=20)
plt.title("World wide Total Case",fontsize=30)
total_case=df.groupby('Date')['Date','Confirmed'].sum().reset_index()
total_case['Date']=pd.to_datetime(total_case['Date'])

ax=sns.pointplot(x=total_case.Date,y=total_case.Confirmed,color='b')
ax.set(xlabel='Date',ylabel='Total Cases')
# Out:
# [Text(0, 0.5, 'Total Cases'), Text(0.5, 0, 'Date')]

# %%
india_case=df[df['Country']=='India']

# %%
last_days=india_case.tail()

# %%
last_days.tail()
# Out:
#              Date Country  Confirmed  Recovered  Deaths  active
# 22827  2020-05-22   India     124794      51824    3726   69244
# 23015  2020-05-23   India     131423      54385    3868   73170
# 23203  2020-05-24   India     138536      57692    4024   76820
# 23391  2020-05-25   India     144950      60706    4172   80072
# 23579  2020-05-26   India     150793      64277    4344   82172

# %%
sns.set(rc={'figure.figsize':(7,5)})
sns.lineplot(x='Date',y='Recovered',data=last_days)
plt.show()

# %%
sns.boxplot(x='Date',y='Deaths',data=last_days,palette='nipy_spectral')

# %%
top=df[df['Deaths']==df['Deaths'].max()]
world=top.groupby('Country')['Confirmed','active','Deaths'].sum().reset_index()
world.head()
# Out:
#   Country  Confirmed   active  Deaths
# 0      US    1680913  1197098   98913

# %%
#sns.stripplot?

# %%
sns.stripplot(df['Confirmed'])

# %%
sns.stripplot('active','Deaths',data=last_days,palette='ocean_r')

# %%
sns.stripplot('Date','Deaths',hue='Recovered',data=last_days,palette='Greys_r')

# %%
sns.swarmplot('Date','Recovered',data=last_days,palette='Spectral_r')

# %%
sns.swarmplot('Date','Confirmed',data=last_days,palette='nipy_spectral_r')

# %%
sns.swarmplot('Date','Confirmed',hue='Deaths',data=last_days,palette='Paired_r')

# %%
sns.violinplot('Date','Deaths',data=last_days)

# %%
sns.violinplot(df['Deaths'])

# %%
sns.violinplot(df['Confirmed'])

# %%
sns.violinplot('Confirmed','Deaths',hue='Recovered',data=last_days)

# %%
plt.violinplot(df['Recovered'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f1ef209bc8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f1ef0e4508>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f1ef210c48>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f1ef210bc8>}

# %%
plt.violinplot(df['Deaths'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f1ef2801c8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f1ef278f88>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f1ef280b88>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f1ef284a48>}

# %%
sns.catplot('Date','Deaths',data=last_days,kind='bar')

# %%
sns.catplot('active','Recovered',data=last_days,palette='ocean_r',kind='bar')

# %%
sns.catplot('Confirmed','Deaths',data=last_days,palette='ocean',kind='box')

# %%
sns.catplot('Recovered','Deaths',data=last_days,palette='ocean',kind='bar')

# %%
china_data=df[df['Country']=='China']

# %%
last_china=china_data.head()

# %%
last_china.head()
# Out:
#            Date Country  Confirmed  Recovered  Deaths  active
# 36   2020-01-22   China        548         28      17     503
# 224  2020-01-23   China        643         30      18     595
# 412  2020-01-24   China        920         36      26     858
# 600  2020-01-25   China       1406         39      42    1325
# 788  2020-01-26   China       2075         49      56    1970

# %%
sns.swarmplot('active','Deaths',data=last_china,palette='binary_r')

# %%
plt.violinplot(df['Deaths'],vert=False)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f1ef781408>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f1ef75b2c8>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f1ef781fc8>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f1ef781708>}

# %%
sns.catplot('Deaths','Recovered',data=last_china,kind='boxen',palette='twilight_r')

# %%
sns.catplot('Deaths','Recovered',data=last_china,kind='box',palette='YlGnBu')

# %%
sns.catplot('Recovered','Deaths',data=last_china,kind='bar',palette='ocean')

# %%
sns.jointplot('Recovered','Deaths',data=last_china,kind='kde')

# %%
sns.jointplot('Recovered','Deaths',data=last_china,kind='reg')

# %%
sns.jointplot('Recovered','Deaths',data=last_days,kind='resid')

# %%
sns.jointplot('Recovered','Deaths',data=last_days,kind='reg')

# %%
sns.jointplot('Deaths','Recovered',data=last_days,kind='scatter')

# %%
sns.jointplot('Recovered','active',data=last_days,kind='kde')

# %%
sns.jointplot('Deaths','Recovered',data=last_china,kind='hex')

# %%
import datetime as dt

# %%
#converting string date to date-time
india_case['Date']=pd.to_datetime(india_case['Date'])
india_case.head()
# Out:
#                              Date Country  Confirmed  Recovered  Deaths  \
# 79  1970-01-01 00:00:00.000737446   India          0          0       0
# 267 1970-01-01 00:00:00.000737447   India          0          0       0
# 455 1970-01-01 00:00:00.000737448   India          0          0       0
# 643 1970-01-01 00:00:00.000737449   India          0          0       0
# 831 1970-01-01 00:00:00.000737450   India          0          0       0
#
#      active
# 79        0
# 267       0
# 455       0
# 643       0
# 831       0

# %%
#convert date-time to ordinal
india_case['Date']=india_case['Date'].map(dt.datetime.toordinal)
india_case.tail()
# Out:
#          Date Country  Confirmed  Recovered  Deaths  active
# 22827  719163   India     124794      51824    3726   69244
# 23015  719163   India     131423      54385    3868   73170
# 23203  719163   India     138536      57692    4024   76820
# 23391  719163   India     144950      60706    4172   80072
# 23579  719163   India     150793      64277    4344   82172

# %%
x=india_case['Date']
y=india_case['Deaths']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=45)

# %%
ln=LinearRegression()

# %%
ln.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
india_case.tail()
# Out:
#          Date Country  Confirmed  Recovered  Deaths  active
# 22827  719163   India     124794      51824    3726   69244
# 23015  719163   India     131423      54385    3868   73170
# 23203  719163   India     138536      57692    4024   76820
# 23391  719163   India     144950      60706    4172   80072
# 23579  719163   India     150793      64277    4344   82172

# %%
predle=ln.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print(mean_squared_error(y_test,predle))
print(mean_absolute_error(y_test,predle))
# Out:
# 2157996.3622448975
# 1076.780612244898

# %%
from sklearn.externals import joblib

# %%
joblib.dump(ln,'covidfile.obj')
# Out:
# ['covidfile.obj']

# %% [raw]
# In this dataset i am use the linear regression for predict the death values of countrys.
# I am only predict the death rate of India, in this dataset.
# We can also predict the all countrys death rate, only change the datetime to ordinal of all dataframe value.
